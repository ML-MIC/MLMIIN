# %% [markdown]
# ---
#
# # FINAL EXAM MACHINE LEARNING II
#
# date: "14 May 2026"
#
# author:
# Fernando San Segundo Badahona & Néstor Rodríguez Pérez
#
#
# ---

# %% [markdown]
# <h1 style="color:red">
# Fill your name here
# </h1>

# %% [markdown]
# <h2 style="color:red;">Exam instructions: read carefully!</h2>
#
# #### Using this notebook
#
# - **[Use this Jupyter notebook]{.underline}** to complete the required tasks. Keep the sectioning structure of the notebook and insert the code cells you need in the corresponding sections.Be mindful of the format and sectioning of your work, as it will be considered in grading.
#
# - The notebook should contain the code with your **analysis** and **it must be reproducible**. Set the random seeds to ensure that.
#
# - The **most important part of your work is the comments and interpretation** of the analysis results obtained. **Do not include uncommented figures**. Remember to include a **conclusion section** at the end.
#
#
# #### Submitting your work
#
# Once you have finished:
# + **Make sure that your name appears on the top cells of the notebook.**
# + **Make sure to save this notebook.**
# + **Make sure that you are logged into your university account and use the link to upload the notebook**
# https://upcomillas-my.sharepoint.com/:f:/g/personal/fsansegundo_comillas_edu/IgADJSVTYjfNQp9Ox22-7BQ-AaomoPGeDPKoLA3L5yGnJ4s

# %% [markdown]
# ::: {.callout-warning icon=false}
#
# **Evita dedicar tiempo a generar código o gráficas no solicitadas.**
# **Do not spend time on code / plots that were not asked for**
#
# :::

# %% [markdown]
# # **Classifying an unlabeled dataset** (6 points)
#
# The dataset `ml_dataset` has been artificially made for this problem. It contains 600 observations with 15 features each.
#
# The objective of the following questions is to apply unsupervised learning techniques to this dataset to later apply a classification model.
#
# **You DO NOT need to carry out a full EDA (delete NaNs, delete outliers, pairplot etc.) as you did with the Classification assignment**
#
# For your convenience, we import in the next cell some of the libraries for unsupervised learning we have seen in the course

# %%
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import sklearn
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans
from sklearn.cluster import DBSCAN
from sklearn.mixture import GaussianMixture
from sklearn.cluster import AgglomerativeClustering

# %% [markdown]
# ::: {.callout-tip icon="false}
# ### Question 0 : PCA (0.5 points)
#
#
#
# * Perform PCA on the data.
# * Using the two first principal components, indicate which features are the most important for each principal component and if you can observe any correlations between features
# * How many principal components you would keep in order to explain more than 90% of the variance of the data?
# * **Use these principal components (>90% of variance) for the rest of the questions.**
#
# :::

# %% [markdown]
# ::: {.callout-tip icon="false}
# ### Question 1 : KMEANS (0.5 points)
#
# **Using the number of principal components that explain at least 90% of the variance:**
# * Apply **KMEANS** clustering to the dataset.
# * You have to **justify the number of clusters** you choose.
# * **Visualize the clusters in a 2D plot.** Discuss if they make sense
# :::

# %% [markdown]
# ::: {.callout-tip icon="false}
# ### Question 2 : AGGLOMERATIVE CLUSTERING (0.5 point)
# **Using the number of principal components that explain at least 90% of the variance:**
# * Apply **Agglomerative clustering** to the dataset.
# * **Justify the number of clusters** you would choose based on the results of the Agglomerative clustering.
# * **Visualize the clusters in a 2D plot.** Discuss if they make sense
# :::

# %% [markdown]
# ::: {.callout-tip icon="false}
# ### Question 3 : GMM (1.5 points)
# **Using the number of principal components that explain at least 90% of the variance:**
# * Apply **GMM** clustering to the dataset. Indicate to GMM the number of clusters you best consider based on the results of previous questions.
# * When applying **GMM**, **try three different `covariance_type`**, visualize their results, and calculate the **Mutual Information index** of their outcome compared to the output of **KMEANS**.
# * Indicate conclusions for the different clustering techniques. Indicate which one you would use to cluster new observations.
# :::

# %% [markdown]
# ::: {.callout-tip icon="false}
# ### Question 4: Dataset for classification (1 point)
#
# You are asked to train a **Decision Tree Classifier** on the dataset (Continue using the Principal Components that explain at least 90% of variance)
#
# * As **Training dataset** you need to use a new dataset with 1000 observations with the same distribution as the original dataset. Generate such dataset with GMM. **Justify the number of components you choose for the density estimation based on AIC and BIC.**
#
# * As **Test dataset** use the original dataset.
#
# * Since you need labels for the observations, use the best GMM model you obtained in Question 3 to assign the labels to both the training and test dataset.
#
# * Classify a decision tree model (**looking for good hyperparameters**) and discuss its performance. Does it make sense to train a classification algorithm on sintetic data? Does it perform well when applying it to real data (test dataset)?
#
# :::

# %% [markdown]
# ::: {.callout-tip icon="false}
# ### Question 5: Classification with the original dataset (1 point)
#
# Similarly to Question 4, now train the  **Decision Tree Classifier** **using the original dataset (Continue using the Principal Components that explain at least 90% of variance)**. This means that you need to apply train/test split.
#
# *  Does it make sense to train a classification algorithm on sintetic data? Does it perform well when applying it to real data (test dataset)?
# * Compare the results of Question 4 and 5.
#
# :::

# %% [markdown]
# ::: {.callout-tip icon="false}
# ### Question 6: Classification with the original dataset without using PCA(1 point)
#
# Similarly to Question 5, now train the  **Decision Tree Classifier** **using the original dataset (WITHOUT APPLYING PCA, USING ALL THE FEATURES)**. (separate into training and test)
#
# * Discuss the results.
#
# :::
