# %% [markdown]
# ---
#
# # RETAKE EXAM MACHINE LEARNING II
#
# date: "9 June 2026"
#
# author:
# Fernando San Segundo Badahona & Néstor Rodríguez Pérez
#
#
# ---

# %% [markdown]
# `fill here your name`

# %% [markdown]
# ::: {.callout-warning icon=false}
#
# **Evita dedicar tiempo a generar código o gráficas no solicitadas.**
#
# No se evaluarán y sólo servirán para consumir tiempo del examen.
# :::

# %% [markdown]
# # **Working with a seeds dataset** (6 points)
#
# The dataset `seedDataSet` contains a set of input variables V1,…, V7 that describe the geometry of plant seeds. We believe that the data contains seeds from several species of plants.
#
# The objective of the following questions is to apply unsupervised learning techniques to this dataset to later apply a classification model.
#
# **You DO NOT need to carry out a full EDA (delete NaNs, delete outliers, pairplot etc.) as you did with the Classification assignment**
#
# For your convenience, we import in the next cell some of the libraries for unsupervised learning we have seen in the course

# %%
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import sklearn
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans
from sklearn.cluster import DBSCAN
from sklearn.mixture import GaussianMixture
from sklearn.cluster import AgglomerativeClustering

# %%
df= pd.read_csv('seedDataSet.csv')
df.head()
# Out:
#       V1     V2      V3     V4     V5     V6     V7
# 0  15.26  14.84  0.8710  5.763  3.312  2.221  5.220
# 1  14.88  14.57  0.8811  5.554  3.333  1.018  4.956
# 2  14.29  14.09  0.9050  5.291  3.337  2.699  4.825
# 3  13.84  13.94  0.8955  5.324  3.379  2.259  4.805
# 4  16.14  14.99  0.9034  5.658  3.562  1.355  5.175

# %% [markdown]
# ::: {.callout-tip icon="false}
# ### Question 0 : PCA (0.5 points)
#
#
#
# * Perform PCA on the data.
# * Using the two first principal components, indicate which features are the most important for each principal component and if you can observe any correlations between features
# * How many principal components you would keep in order to explain more than 90% of the variance of the data?
# * Use these principal components (>90% of variance) for the rest of the questions.
#
# :::

# %% [markdown]
# ::: {.callout-tip icon="false}
# ### Question 1 : KMEANS (0.5 points)
#
# **Using the number of principal components that explain at least 90% of the variance:**
# * Apply **KMEANS** clustering to the dataset.
# * You have to **justify the number of clusters** you choose.
# * **Visualize the clusters in a 2D plot.** Discuss if they make sense
# :::

# %% [markdown]
# ::: {.callout-tip icon="false}
# ### Question 2 : AGGLOMERATIVE CLUSTERING (0.5 point)
# **Using the number of principal components that explain at least 90% of the variance:**
# * Apply **Agglomerative clustering** to the dataset.
# * **Justify the number of clusters** you would choose based on the results of the Agglomerative clustering.
# * **Visualize the clusters in a 2D plot.** Discuss if they make sense
# :::

# %% [markdown]
# ::: {.callout-tip icon="false}
# ### Question 3 : Comparison of clustering with and without PCs (1 points)
# * **Now, USING THE ORIGINAL DATA, apply KMEANS and Agglomerative clustering, selecting an appropriate and justified number of clusters**
# * For **KMEANS**, compare the clustering model obtained previously with PCs against this new one that uses the original data. Use **appropriate metrics** for this comparison.
# * For **Agglomerative clustering**, compare the clustering model obtained previously with PCs against this new one that uses the original data. Use **appropriate metrics** for this comparison.
# :::

# %% [markdown]
# ::: {.callout-tip icon="false}
# ### Question 4 : DBSCAN (0.5 points)
# **Using the number of principal components that explain at least 90% of the variance:**
# * Apply **DBSCAN** clustering to the dataset. Discuss the process to adjustment the model.
# * Visualize the clusters of DBSCAN in a 2D plot.
# :::

# %% [markdown]
# ::: {.callout-tip icon="false}
# ### Question 5 : GMM and comparison of models (1 points)
# **Using the number of principal components that explain at least 90% of the variance:**
# * Apply **GMM** clustering to the dataset. Indicate to GMM the number of clusters you best consider based on the results of previous questions.
# * **Considering that the labels assigned by GMM are the correct ones**, compare the performance of previous clustering methods using metrics.
# :::

# %% [markdown]
# ::: {.callout-tip icon="false}
# ### Question 4: Dataset for classification (2 point)
#
# You are asked to train a **Random Forest** and a **KNN** model on the dataset (Continue using the Principal Components that explain at least 90% of variance)
#
# * As **Training dataset** you need to use a new dataset with 1000 observations with the same distribution as the original dataset. Generate such dataset with GMM. **Justify the number of components you choose for the density estimation based on AIC and BIC.**
#
# * As **Test dataset** use the original dataset.
#
# * Since you need labels for the observations, use the GMM model you obtained in the previous question to assign the labels to both the training and test dataset.
#
# * Classify a Random Forest model and a KNN model and discuss their performance
#
# :::
